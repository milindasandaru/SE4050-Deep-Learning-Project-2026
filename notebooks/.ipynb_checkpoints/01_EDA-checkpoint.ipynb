# %% [markdown]
# ## 1. Load the Dataset
#
# The PhiUSIIL Phishing URL Dataset is obtained from the UCI Machine Learning
# Repository. It contains website and URL-related features that can be used to
# classify websites as legitimate or phishing.
#
# The raw dataset is loaded without modifying the original data.

# %%
# Get the CSV file from the raw data directory
csv_file = list(/data/.glob("*.csv"))[0]

# Load the dataset
df = pd.read_csv(csv_file)

print("Dataset loaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Get the CSV file from the raw data directory
# ----> 2 csv_file = list(data_path.glob("*.csv"))[0]
#       4 # Load the dataset
#       5 df = pd.read_csv(csv_file)
#
# NameError: name 'data_path' is not defined
